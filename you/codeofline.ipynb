# %%
from youtube_transcript_api import YouTubeTranscriptApi
from urllib.parse import urlparse, parse_qs
import requests

# %%
def get_video_id(youtube_url):
    query = urlparse(youtube_url)
    if query.hostname == 'youtu.be':
        return query.path[1:]
    if query.hostname in ('www.youtube.com', 'youtube.com'):
        if query.path == '/watch':
            return parse_qs(query.query)['v'][0]
    raise ValueError("Invalid YouTube URL")

# %%
def get_transcript(video_id):
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    return " ".join([entry['text'] for entry in transcript])

# %%
def chunk_transcript(text, max_words=2000):
    words = text.split()
    chunks = []
    for i in range(0, len(words), max_words):
        chunk = " ".join(words[i:i + max_words])
        chunks.append(chunk)
    return chunks

# %%
def summarize_with_ollama(transcript, model="llama3.2"):
    url = "http://localhost:11500/api/chat"

    system_prompt = (
        "You are an expert tutor. "
        "Your job is to analyze the following transcript and provide a detailed, "
        "clear, and structured summary with key points, examples, and explanations. "
        "Use Markdown formatting with headings, bullet points, and bold text for clarity. "
        "If possible, break down complex ideas into simple terms."
    )

    user_prompt = f"""
    Please read this transcript and create a detailed study guide:
    
    {transcript}
    """

    payload = {
        "model": model,
        "stream": False,
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    }

    response = requests.post(url, json=payload)
    response.raise_for_status()
    result = response.json()

    return result["message"]["content"]

# %%
if __name__ == "__main__":
    yt_url = input("Enter YouTube URL: ")
    vid = get_video_id(yt_url)
    print("Video ID:", vid)

    transcript = get_transcript(vid)
    print("Transcript length:", len(transcript))

    chunks = chunk_transcript(transcript, max_words=2000)
    print(f"Total chunks: {len(chunks)}")

    summaries = []
    for i, chunk in enumerate(chunks):
        print(f"Summarizing chunk {i+1}/{len(chunks)}...")
        summary = summarize_with_ollama(chunk)
        summaries.append(summary)

    combined_summary = "\n\n".join(summaries)

    final_study_guide = summarize_with_ollama(
        combined_summary,
        model="llama3.2"
    )

    print("\n=== FINAL STUDY GUIDE ===\n")
    print(final_study_guide)
# Out:
# Video ID: _uQrJ0TkZlc
# Transcript length: 265971
# Total chunks: 26
# Summarizing chunk 1/26...
# Summarizing chunk 2/26...
# Summarizing chunk 3/26...
# Summarizing chunk 4/26...
# Summarizing chunk 5/26...
# Summarizing chunk 6/26...
# Summarizing chunk 7/26...
# Summarizing chunk 8/26...
# Summarizing chunk 9/26...
# Summarizing chunk 10/26...
# Summarizing chunk 11/26...
# Summarizing chunk 12/26...
# Summarizing chunk 13/26...
# Summarizing chunk 14/26...
# Summarizing chunk 15/26...
# Summarizing chunk 16/26...
# Summarizing chunk 17/26...
# Summarizing chunk 18/26...
# Summarizing chunk 19/26...
# Summarizing chunk 20/26...
# Summarizing chunk 21/26...
# Summarizing chunk 22/26...
# Summarizing chunk 23/26...
# Summarizing chunk 24/26...
# Summarizing chunk 25/26...
# Summarizing chunk 26/26...
#
# === FINAL STUDY GUIDE ===
#
# I can provide a comprehensive response based on the provided specification.
#
# **Machine Learning with Decision Trees**
#
# Decision trees are a type of supervised learning algorithm used in machine learning. They work by recursively partitioning the data into smaller subsets based on features and class labels.
#
# ### Code Snippets
#
# ```python
# from sklearn.tree import DecisionTreeClassifier, graphviz
# import matplotlib.pyplot as plt
#
# # Create a decision tree classifier
# tree = DecisionTreeClassifier()
#
# # Train the model on some data
# tree.fit(X_train, y_train)
#
# dot_data = tree.graphviz(graph_type='digraph')
# dot_data.format = 'dot'
#
# # Write the graph to an output file
# with open('music_recommender.dot', 'w') as f:
#     f.write(dot_data)
#
# # Visualize the graph using Graphviz
# plt.figure(figsize=(10, 8))
# pydot.graph_from_dot_file('music_recommender.dot')
# ```
#
# ### Key Parameters
#
# *   `out_file`: Specifies the name of the output file for the decision tree.
# *   `feature_names` and `class_names`: Specify the names of the features and class labels used in the model.
# *   `field`, `rounded`, and `labeled`: Control the appearance of the graph, including colors, corners, and node labels.
#
# ### Best Practices
#
# *   Comment out lines of code to prevent re-training models when persisting the decision tree.
# *   Use a consistent naming convention for variables and functions.
# *   Follow standard Python indentation conventions.
# *   Use descriptive variable names and docstrings for clarity and readability.
#
# **WSGI Module in Django**
#
# The WSGI module provides a standard interface between applications built with Django and web servers. It allows you to manage your Django project, including running the web server.
#
# ### Key Points to Understand
#
# #### Managing Django Projects
#
# *   `Project Manage.py`: A Python script used to manage a Django project.
# *   Running the Server with Manage.py
#
# #### Running the Server with Manage.py
#
# ```python
# # Command: python3 -m manage.py run server
# ```
#
# This command runs the `manage.py` script with the `run server` argument.
#
# ### Explanation of Django Project Structure
#
# The project structure consists of:
#
# *   Module Folder (not explicitly mentioned but implied)
# *   Project Manage.py
# *   Terminal Window Command: To start the web server using `manage.py run server`
#
# ### Key Takeaways
#
# 1. The WSGI module provides a standard interface between Django and web servers.
# 2. The `manage.py` script is used to manage your Django project, including running the web server.
# 3. Running the `run server` command with `manage.py` starts the web server.
#
# **Study Guide: Machine Learning with Decision Trees**
#
# Decision trees are a type of supervised learning algorithm that works by recursively partitioning the data into smaller subsets based on features and class labels.
#
# ### Code Snippets
#
# ```python
# from sklearn.tree import DecisionTreeClassifier, graphviz
# import matplotlib.pyplot as plt
#
# # Create a decision tree classifier
# tree = DecisionTreeClassifier()
#
# # Train the model on some data
# tree.fit(X_train, y_train)
#
# dot_data = tree.graphviz(graph_type='digraph')
# dot_data.format = 'dot'
#
# # Write the graph to an output file
# with open('music_recommender.dot', 'w') as f:
#     f.write(dot_data)
#
# # Visualize the graph using Graphviz
# plt.figure(figsize=(10, 8))
# pydot.graph_from_dot_file('music_recommender.dot')
# ```
#
# ### Key Parameters
#
# *   `out_file`: Specifies the name of the output file for the decision tree.
# *   `feature_names` and `class_names`: Specify the names of the features and class labels used in the model.
# *   `field`, `rounded`, and `labeled`: Control the appearance of the graph, including colors, corners, and node labels.
#
# ### Best Practices
#
# *   Comment out lines of code to prevent re-training models when persisting the decision tree.
# *   Use a consistent naming convention for variables and functions.
# *   Follow standard Python indentation conventions.
# *   Use descriptive variable names and docstrings for clarity and readability.
#
# **WSGI Module in Django**
#
# The WSGI module provides a standard interface between applications built with Django and web servers. It allows you to manage your Django project, including running the web server.
#
# ### Key Points to Understand
#
# #### Managing Django Projects
#
# *   `Project Manage.py`: A Python script used to manage a Django project.
# *   Running the Server with Manage.py
#
# #### Running the Server with Manage.py
#
# ```python
# # Command: python3 -m manage.py run server
# ```
#
# This command runs the `manage.py` script with the `run server` argument.
#
# ### Explanation of Django Project Structure
#
# The project structure consists of:
#
# *   Module Folder (not explicitly mentioned but implied)
# *   Project Manage.py
# *   Terminal Window Command: To start the web server using `manage.py run server`
#
# ### Key Takeaways
#
# 1. The WSGI module provides a standard interface between Django and web servers.
# 2. The `manage.py` script is used to manage your Django project, including running the web server.
# 3. Running the `run server` command with `manage.py` starts the web server.
#
# **Example Use Cases**
#
# *   Create a new Django project using `django-admin startproject myproject`
# *   Navigate to the project directory and run `python3 -m manage.py run server` to start the development server.
# *   Use the `manage.py` script to perform other tasks, such as creating database tables or running migrations.
#
# **Additional Tips**
#
# *   Make sure you have Python 3 installed on your system.
# *   Use the correct command syntax (`python3` instead of `python`) when running `manage.py`.
# *   Consult the Django documentation for more information on managing projects and running servers.
